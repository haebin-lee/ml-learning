# %% [markdown]
# ### Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('./data/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X, y = df.iloc[:, 0], df.iloc[:,1]

# %%
import torch

train_x = torch.tensor(X.to_numpy())
train_x = train_x.float() #

# %%
class DiabetesMLP:
    def __init__():
        return

# %%
## April 15th

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.001, momentum=0.9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 criterion = torch.nn.CrossEntropyLoss()
# ----> 2 optimizer = torch.optim.SGD()
#
# TypeError: SGD.__init__() missing 1 required positional argument: 'params'

# %%
# Training loop

epochs = 100
train_loss = []
valid_loss = []

for epoch in range(epochs):
    batch_loss = []
    model.train()
    # Train a batch 
    for features, targets in train_loader: 
        # Get output 
        output = model.forward(features)
        
        # Calculate the loss
        loss = criterion(output, target)
        batch_loss.append(loss)
        
        optimizer.zero_Grad() # Remove previous gradients
        loss.backward() # What the updates should be
        optimizer.step() # Update weight & bias

    # For each epoch:
    model.eval()
    
    # Training loss: 
    train_loss.append(sum(batch_loss) / len(batch_loss))
    # Valid_loss, etc. 
    hyp_valid = model.foward(valid_x)
    c = torch.argmax(hyp_valid, dim=1)
    
    valid_loss.append(criterion(hyp_valid, valid_y).item())
    valid_acc = (c == valid_y).sum().item() / valid_y.shape[0] # .item(): change to natural number type from tensor type
    print('Valid acc: ', valid_acc, 'Valid loss: ', valid_loss[-1])

# %%
# epochs vs train & epoch vs valid
def plot_loss_curve(epochs, train_loss, valid_loss): 
    plt.plot(epochs, train_loss, label='Train loss')
    plt.plot(epochs, valid_loss, label='Valid loss')
    plt.xlabel('Epoch')
    plt.ylabel('Cross Entropy Loss')
    plt.legend()
    plt.show()

plot_loss_curves(np.linspace(1, epochs, epochs), train_loss, valid_loss)

# %%
hyp_valid = model.foward(valid_x)
hyp_valid

# %% [markdown]
# **argmax**
#
# [0.7, 0.1, 0.2]
# -> argmax: 0

# %%
c = torch.argmax(hyp_valid, dim=1)
(c == valid_y).sum().item() / valid_y.shape[0] # .item(): change to natural number type from tensor type
